# %%
def sum_of_squares(v):
        return sum(v_i**2 for v_i in v)

# %%
k = [1,2,3,4,5]
print (sum_of_squares(k))
# Out:
# 55

# %%
1**2+2**2+3**2+4**2+5**2
# Out:
# 55

# %%
u = var('u')
f = u^3+u^4+u^2
revolution_plot3d(f, (u,0,2), show_curve=True, opacity=0.7).show(aspect_ratio=(1,1,1))
# Out:
# Graphics3d Object
